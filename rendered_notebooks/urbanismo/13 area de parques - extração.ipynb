# %%
import pandas as pd
import geopandas as gpd
from os import path, makedirs

from core.downloads.geosampa import get_capabilities, get_features

# %% [markdown]
# # Mapa 06 - Área de parques por subprefeitura

# %% [markdown]
# Esse notebook é responsável pelo download dos dados utilizados no dashboard https://datasp.observatorio.tcm.sp.gov.br/urbanismo#area-de-parques-municipais-e-estaduais-2024 do DataSP. No ano de 2025 os dados foram obtidos manualmente, mas em 2026 serão obtidos via script para os anos de referência de 2024 e 2025.

# %% [markdown]
# # Extração dos dados

# %% [markdown]
# ## Subprefeituras

# %%
get_capabilities(filter="subp")
# Out:
# [{'name': 'geoportal:GEOSAMPA_v_praca_largo',
#   'title': 'Cadastro de Praças e Largos',
#   'abstract': 'Localização das praças e largos no território do município de São Paulo, com base nas informações repassadas por subprefeituras, SF e SEGES/CGPATRI.'},
#  {'name': 'geoportal:perimetro_zoneamento_revogado_lei13885',
#   'title': 'Perímetro Zona de Uso - Revogado - Lei 13.885/04',
#   'abstract': 'A Lei de Zoneamento estabelece normas complementares ao Plano Diretor Estratégico, institui os Planos Regionais Estratégicos das Subprefeituras, dispõe sobre o parcelamento, disciplina e ordena o Uso e Ocupação do Solo do Município de São Paulo. Os perímetros de zona de uso foram vetorizados perante o estabelecido na Lei nº 13.885/2004, tendo como base cartográfica o Mapa Digital da Cidade (MDC).'},
#  {'name': 'geoportal:sede_subprefeitura',
#   'title': 'Subprefeituras',
#   'abstract': 'Localização das sedes físicas das Subprefeituras da Cidade de São Paulo.'},
# ...

# %%
subprefeituras = get_features("geoportal:subprefeitura")
subprefeituras
# Out:
#                   id  cd_identificador_subprefeitura cd_subprefeitura  \
# 0    subprefeitura.1                               1               02
# 1    subprefeitura.2                               2               03
# 2    subprefeitura.3                               3               04
# 3    subprefeitura.4                               4               05
# 4    subprefeitura.5                               5               06
# 5    subprefeitura.6                               6               07
# 6    subprefeitura.7                               7               21
# 7    subprefeitura.8                               8               22
# 8    subprefeitura.9                               9               23
# 9   subprefeitura.10                              10               24
# 10  subprefeitura.11                              11               27
# 11  subprefeitura.12                              12               28
# ...

# %% [markdown]
# ## Parques

# %%
get_capabilities(filter="parque")
# Out:
# [{'name': 'geoportal:pde_estrategia_desenvolvimento_economico',
#   'title': 'Estratégias de Desenvolvimento Econômico',
#   'abstract': 'Estratégias de Desenvolvimento Econômico, considerando os PEDEs, Polo de Economia Criativa e Parque Tecnológico.'},
#  {'name': 'geoportal:pde_parque_municipal',
#   'title': 'Parques Municipais (Mapa 5)',
#   'abstract': 'Mapa 5 - Parques Municipais Existentes e Propostos.'},
#  {'name': 'geoportal:GEOSAMPA_cadparcs_parque_unidade_conservacao',
#   'title': 'Parques e Unidades de Conservação',
#   'abstract': ''},
#  {'name': 'geoportal:iluminacao_publica',
#   'title': 'Pontos de iluminação pública',
# ...

# %%
parques = get_features("geoportal:GEOSAMPA_cadparcs_parque_unidade_conservacao")
parques
# Out:
#                                           id  \
# 0    cadparcs_parque_unidade_conservacao.356
# 1    cadparcs_parque_unidade_conservacao.364
# 2    cadparcs_parque_unidade_conservacao.285
# 3    cadparcs_parque_unidade_conservacao.329
# 4     cadparcs_parque_unidade_conservacao.45
# ..                                       ...
# 371  cadparcs_parque_unidade_conservacao.190
# 372   cadparcs_parque_unidade_conservacao.20
# 373   cadparcs_parque_unidade_conservacao.44
# 374  cadparcs_parque_unidade_conservacao.323
# 375  cadparcs_parque_unidade_conservacao.378
#
#      cd_identificador_cadparcs_parque_unidade_conservacao  \
# 0                                                  356
# 1                                                  364
# 2                                                  285
# 3                                                  329
# 4                                                   45
# ..                                                 ...
# ...

# %% [markdown]
# # Exportando os arquivos

# %% [markdown]
# Neste notebook, vamos apenas salvar os arquivos extraídos na pasta de entrada de dados.

# %%
output_dir = path.join('data', 'cache', 'urbanismo')

if not path.exists(output_dir):
    makedirs(output_dir)

for c, gdf in [('subprefeituras', subprefeituras),
               ('parques', parques),
               ]:
    filename=path.join(output_dir, c)
    gdf.to_file(f'{filename}.gpkg', layer=c, driver='GPKG')
