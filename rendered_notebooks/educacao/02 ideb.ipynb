# %%
import os
import pandas as pd
from unidecode import unidecode
from dotenv import load_dotenv
import requests, zipfile
from io import StringIO, BytesIO

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# # Extração e transformação inicial

# %% [markdown]
# Durante a evolução do projeto, também foi sugerida a inclusão do IDEB do município como indicador educacional ao dashboard de visão geral. Os dados são divulgados de maneira agregada para o município separados por anos iniciais, anos finais e ensino médio. Vamos obtê-los diretamente do site do INEP.

# %%
def get_ideb(ciclo: str) -> pd.DataFrame:
    """
    Baixa e processa dados do IDEB para o município de São Paulo.
    
    Parâmetros:
    -----------
    ciclo : str
        O ciclo educacional desejado. Deve ser um dos valores:
        - 'anos_iniciais': Anos iniciais do ensino fundamental
        - 'anos_finais': Anos finais do ensino fundamental  
        - 'ensino_medio': Ensino médio
    
    Retorna:
    --------
    pd.DataFrame
        DataFrame com os dados do IDEB filtrados para o município de São Paulo
        (código 3550308).
    
    Levanta:
    --------
    ValueError
        Se o parâmetro 'ciclo' não for um dos valores válidos.
    
    Exemplo:
    --------
    >>> df_ideb = get_ideb('anos_iniciais')
    >>> print(df_ideb.head())
    """
    if ciclo not in ['anos_iniciais', 'anos_finais', 'ensino_medio']:
        raise ValueError("Ciclo deve ser 'anos_iniciais', 'anos_finais' ou 'ensino_medio'")
    
    url = f'https://download.inep.gov.br/ideb/resultados/divulgacao_{ciclo}_municipios_2023.zip'
    with requests.get(url) as r:
        with zipfile.ZipFile(BytesIO(r.content)) as z:
            file_path = f'divulgacao_{ciclo}_municipios_2023/divulgacao_{ciclo}_municipios_2023.xlsx'
            df = pd.read_excel(z.open(file_path), skiprows=9)

    df = df[df['CO_MUNICIPIO'] == 3550308]
    return df

# %%
df_ideb_iniciais = get_ideb('anos_iniciais')
df_ideb_iniciais
# Out:
#      SG_UF  CO_MUNICIPIO NO_MUNICIPIO       REDE VL_APROVACAO_2005_SI_4  \
# 9940    SP     3550308.0    São Paulo    Federal                      -
# 9941    SP     3550308.0    São Paulo   Estadual                   95.1
# 9942    SP     3550308.0    São Paulo  Municipal                   94.7
# 9943    SP     3550308.0    São Paulo    Pública                   94.9
#
#      VL_APROVACAO_2005_SI VL_APROVACAO_2005_1 VL_APROVACAO_2005_2  \
# 9940                    -                   -                   -
# 9941                    -                95.2                97.1
# 9942                    -                96.5                98.1
# 9943                    -                95.8                97.5
#
#      VL_APROVACAO_2005_3 VL_APROVACAO_2005_4  ... VL_OBSERVADO_2021  \
# 9940                   -                   -  ...                 -
# 9941                97.2                  91  ...                 6
# 9942                98.3                87.6  ...               5.7
# 9943                97.7                89.3  ...               5.9
#
#      VL_OBSERVADO_2023 VL_PROJECAO_2007 VL_PROJECAO_2009 VL_PROJECAO_2011  \
# 9940               6.5                -                -              5.7
# 9941               6.1              4.7                5              5.4
# 9942               5.6              4.1              4.5              4.9
# 9943               5.9              4.4              4.7              5.1
#
#      VL_PROJECAO_2013 VL_PROJECAO_2015 VL_PROJECAO_2017 VL_PROJECAO_2019  \
# 9940                6              6.2              6.5              6.7
# 9941              5.7              5.9              6.2              6.4
# 9942              5.2              5.4              5.7                6
# 9943              5.4              5.7              5.9              6.2
#
#      VL_PROJECAO_2021
# 9940              6.9
# 9941              6.6
# 9942              6.2
# 9943              6.4
#
# [4 rows x 122 columns]

# %%
df_ideb_finais = get_ideb('anos_finais')
df_ideb_finais
# Out:
#       SG_UF  CO_MUNICIPIO NO_MUNICIPIO       REDE VL_APROVACAO_2005_SI_4  \
# 10053    SP     3550308.0    São Paulo   Estadual                   85.5
# 10054    SP     3550308.0    São Paulo  Municipal                   93.6
# 10055    SP     3550308.0    São Paulo    Pública                   88.8
#
#       VL_APROVACAO_2005_1 VL_APROVACAO_2005_2 VL_APROVACAO_2005_3  \
# 10053                88.9                88.6                87.4
# 10054                96.5                95.7                  95
# 10055                92.2                91.6                90.5
#
#       VL_APROVACAO_2005_4 VL_INDICADOR_REND_2005  ... VL_OBSERVADO_2021  \
# 10053                76.9               0.851411  ...               5.1
# 10054                  86               0.930964  ...               5.1
# 10055                80.3               0.883665  ...               5.1
#
#       VL_OBSERVADO_2023 VL_PROJECAO_2007 VL_PROJECAO_2009 VL_PROJECAO_2011  \
# 10053               4.9              3.8                4              4.3
# 10054               4.8              4.1              4.3              4.6
# 10055               4.8                4              4.1              4.4
#
#       VL_PROJECAO_2013 VL_PROJECAO_2015 VL_PROJECAO_2017 VL_PROJECAO_2019  \
# 10053              4.7                5              5.3              5.5
# 10054                5              5.3              5.6              5.8
# 10055              4.8              5.2              5.4              5.6
#
#       VL_PROJECAO_2021
# 10053              5.8
# 10054                6
# 10055              5.9
#
# [3 rows x 112 columns]

# %%
df_ideb_medio = get_ideb('ensino_medio')
df_ideb_medio
# Out:
#      SG_UF  CO_MUNICIPIO NO_MUNICIPIO       REDE VL_APROVACAO_2017_SI_4  \
# 8058    SP     3550308.0    São Paulo   Estadual                   81.6
# 8059    SP     3550308.0    São Paulo    Federal                   88.4
# 8060    SP     3550308.0    São Paulo  Municipal                   85.3
# 8061    SP     3550308.0    São Paulo    Pública                   81.7
#
#      VL_APROVACAO_2017_1 VL_APROVACAO_2017_2 VL_APROVACAO_2017_3  \
# 8058                74.2                82.2                90.5
# 8059                85.2                86.8                96.8
# 8060                79.3                84.8                92.1
# 8061                74.3                82.3                90.5
#
#      VL_APROVACAO_2017_4 VL_INDICADOR_REND_2017  ... VL_NOTA_MEDIA_2021  \
# 8058                   -               0.817611  ...           4.713662
# 8059                   -               0.893165  ...           6.597057
# 8060                93.3               0.869969  ...           4.711535
# 8061                93.3               0.844283  ...           4.727806
#
#      VL_NOTA_MATEMATICA_2023 VL_NOTA_PORTUGUES_2023 VL_NOTA_MEDIA_2023  \
# 8058                  265.35                 277.16           4.565442
# 8059                  327.41                 330.84           6.240664
# 8060                  266.21                  273.1           4.516742
# 8061                  265.86                 277.57           4.578743
#
#      VL_OBSERVADO_2017 VL_OBSERVADO_2019 VL_OBSERVADO_2021 VL_OBSERVADO_2023  \
# 8058               3.5               3.9               4.3               4.1
# 8059               6.3               6.7                 6                 6
# 8060               3.5               3.7               4.5               4.3
# 8061               3.6               4.1               4.4               4.2
#
#      VL_PROJECAO_2019 VL_PROJECAO_2021
# 8058              3.7              3.9
# 8059              6.5              6.7
# 8060              3.7                4
# 8061              3.8                4
#
# [4 rows x 46 columns]

# %% [markdown]
# # Transformação e mesclagem de dados

# %% [markdown]
# Primeiro, vamos concatenar os dados dos três níveis de ensino em um único DataFrame, adicionando uma coluna para identificar o nível de ensino correspondente.

# %%
df_ideb = pd.concat(
    [df_ideb_iniciais
    .assign(CICLO='Anos Iniciais'),
    df_ideb_finais
    .assign(CICLO='Anos Finais'),
    df_ideb_medio
    .assign(CICLO='Ensino Médio')]
)

df_ideb
# Out:
#       SG_UF  CO_MUNICIPIO NO_MUNICIPIO       REDE VL_APROVACAO_2005_SI_4  \
# 9940     SP     3550308.0    São Paulo    Federal                      -
# 9941     SP     3550308.0    São Paulo   Estadual                   95.1
# 9942     SP     3550308.0    São Paulo  Municipal                   94.7
# 9943     SP     3550308.0    São Paulo    Pública                   94.9
# 10053    SP     3550308.0    São Paulo   Estadual                   85.5
# 10054    SP     3550308.0    São Paulo  Municipal                   93.6
# 10055    SP     3550308.0    São Paulo    Pública                   88.8
# 8058     SP     3550308.0    São Paulo   Estadual                    NaN
# 8059     SP     3550308.0    São Paulo    Federal                    NaN
# 8060     SP     3550308.0    São Paulo  Municipal                    NaN
# 8061     SP     3550308.0    São Paulo    Pública                    NaN
#
#       VL_APROVACAO_2005_SI VL_APROVACAO_2005_1 VL_APROVACAO_2005_2  \
# 9940                     -                   -                   -
# 9941                     -                95.2                97.1
# 9942                     -                96.5                98.1
# 9943                     -                95.8                97.5
# 10053                  NaN                88.9                88.6
# 10054                  NaN                96.5                95.7
# 10055                  NaN                92.2                91.6
# 8058                   NaN                 NaN                 NaN
# 8059                   NaN                 NaN                 NaN
# 8060                   NaN                 NaN                 NaN
# 8061                   NaN                 NaN                 NaN
#
#       VL_APROVACAO_2005_3 VL_APROVACAO_2005_4  ... VL_OBSERVADO_2023  \
# 9940                    -                   -  ...               6.5
# 9941                 97.2                  91  ...               6.1
# 9942                 98.3                87.6  ...               5.6
# 9943                 97.7                89.3  ...               5.9
# 10053                87.4                76.9  ...               4.9
# 10054                  95                  86  ...               4.8
# 10055                90.5                80.3  ...               4.8
# 8058                  NaN                 NaN  ...               4.1
# 8059                  NaN                 NaN  ...                 6
# 8060                  NaN                 NaN  ...               4.3
# 8061                  NaN                 NaN  ...               4.2
#
#       VL_PROJECAO_2007 VL_PROJECAO_2009 VL_PROJECAO_2011 VL_PROJECAO_2013  \
# 9940                 -                -              5.7                6
# 9941               4.7                5              5.4              5.7
# 9942               4.1              4.5              4.9              5.2
# 9943               4.4              4.7              5.1              5.4
# 10053              3.8                4              4.3              4.7
# 10054              4.1              4.3              4.6                5
# 10055                4              4.1              4.4              4.8
# 8058               NaN              NaN              NaN              NaN
# 8059               NaN              NaN              NaN              NaN
# 8060               NaN              NaN              NaN              NaN
# 8061               NaN              NaN              NaN              NaN
#
#       VL_PROJECAO_2015 VL_PROJECAO_2017 VL_PROJECAO_2019 VL_PROJECAO_2021  \
# 9940               6.2              6.5              6.7              6.9
# 9941               5.9              6.2              6.4              6.6
# 9942               5.4              5.7                6              6.2
# 9943               5.7              5.9              6.2              6.4
# 10053                5              5.3              5.5              5.8
# 10054              5.3              5.6              5.8                6
# 10055              5.2              5.4              5.6              5.9
# 8058               NaN              NaN              3.7              3.9
# 8059               NaN              NaN              6.5              6.7
# 8060               NaN              NaN              3.7                4
# 8061               NaN              NaN              3.8                4
#
#                CICLO
# 9940   Anos Iniciais
# 9941   Anos Iniciais
# 9942   Anos Iniciais
# 9943   Anos Iniciais
# 10053    Anos Finais
# 10054    Anos Finais
# 10055    Anos Finais
# 8058    Ensino Médio
# 8059    Ensino Médio
# 8060    Ensino Médio
# 8061    Ensino Médio
#
# [11 rows x 123 columns]

# %% [markdown]
# Agora, filtramos apenas a rede municipal.

# %%
df_ideb = df_ideb[df_ideb['REDE'] == 'Municipal'].reset_index(drop=True)
df_ideb
# Out:
#   SG_UF  CO_MUNICIPIO NO_MUNICIPIO       REDE VL_APROVACAO_2005_SI_4  \
# 0    SP     3550308.0    São Paulo  Municipal                   94.7
# 1    SP     3550308.0    São Paulo  Municipal                   93.6
# 2    SP     3550308.0    São Paulo  Municipal                    NaN
#
#   VL_APROVACAO_2005_SI VL_APROVACAO_2005_1 VL_APROVACAO_2005_2  \
# 0                    -                96.5                98.1
# 1                  NaN                96.5                95.7
# 2                  NaN                 NaN                 NaN
#
#   VL_APROVACAO_2005_3 VL_APROVACAO_2005_4  ... VL_OBSERVADO_2023  \
# 0                98.3                87.6  ...               5.6
# 1                  95                  86  ...               4.8
# 2                 NaN                 NaN  ...               4.3
#
#   VL_PROJECAO_2007 VL_PROJECAO_2009 VL_PROJECAO_2011 VL_PROJECAO_2013  \
# 0              4.1              4.5              4.9              5.2
# 1              4.1              4.3              4.6                5
# 2              NaN              NaN              NaN              NaN
#
#   VL_PROJECAO_2015 VL_PROJECAO_2017 VL_PROJECAO_2019 VL_PROJECAO_2021  \
# 0              5.4              5.7                6              6.2
# 1              5.3              5.6              5.8                6
# 2              NaN              NaN              3.7                4
#
#            CICLO
# 0  Anos Iniciais
# 1    Anos Finais
# 2   Ensino Médio
#
# [3 rows x 123 columns]

# %% [markdown]
# Por último, mantemos apenas as colunas relevantes para o nosso dashboard e renomeamos as colunas para um formato mais amigável.

# %%
df_ideb = df_ideb[['CICLO', 'VL_OBSERVADO_2023']]
df_ideb
# Out:
#            CICLO VL_OBSERVADO_2023
# 0  Anos Iniciais               5.6
# 1    Anos Finais               4.8
# 2   Ensino Médio               4.3

# %%
df_ideb = df_ideb.assign(IDEB_2023=pd.to_numeric(df_ideb['VL_OBSERVADO_2023']))
df_ideb = df_ideb.drop(columns='VL_OBSERVADO_2023')
df_ideb
# Out:
#            CICLO  IDEB_2023
# 0  Anos Iniciais        5.6
# 1    Anos Finais        4.8
# 2   Ensino Médio        4.3

# %% [markdown]
# # Armazenamento dos dados

# %% [markdown]
# Finalmente, salvamos os arquivos como csv para utilizarmos no Qlik Sense.

# %%
base_path = os.path.join('data_output', 'educacao')

if not os.path.exists(base_path):
    os.makedirs(base_path)

filepath = os.path.join(base_path, f'ideb-municipal.csv')

df_ideb.to_csv(filepath,
               index=False,
               sep=';',
               decimal=',',
               encoding='utf-8')
